# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VikasKajeepeta2005/FlyRank-Internship-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I selected the Search Performance Optimization lane.
#
# I chose this lane because businesses rely on search traffic to attract users.
# By analyzing search performance data, we can identify which pages have the greatest opportunity for improvement.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Which webpages should be prioritized for SEO improvements to maximize clicks and impressions?
#
# Decision:
# Choose which pages should receive optimization first.
#
# Action:
# Improve page titles, content quality, and keyword targeting.
#
# Cost of a Wrong Decision:
# Time and effort may be spent optimizing pages with little potential, while valuable pages are ignored.
#
# Why Machine Learning?
#
# Machine learning can identify patterns across many metrics that are difficult to detect manually.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Average 90-day impressions:", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 2))
print("Average Position:", round(df["avg_position"].mean(), 2))
# Out:
# Number of rows: 30000
# Number of columns: 44
# Average 90-day impressions: 5200.37
# Average CTR: 0.51
# Average Position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This analysis only identifies patterns in the available dataset.
#
# It does not prove that one variable directly causes another.
#
# Future work will validate any findings before making business recommendations.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
